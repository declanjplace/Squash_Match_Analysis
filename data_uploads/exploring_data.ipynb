# %%
import pandas as pd
import json

# %%
from get_data import get_match_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from get_data import get_match_data
#
# ImportError: cannot import name 'get_match_data' from 'get_data' (c:\Users\Gaming PC\Documents\Coding\Squash_Match_Analysis\data_uploads\get_data.py)

# %%
farags_first_match = get_match_data('farag_jsons_251023', 'jsons_October_2023')[0]
farags_first_match['file_name']

# %%
farags_first_match.keys()

# %%
farags_first_match['matches']

# %%
farags_first_match['matches'][0].keys()
